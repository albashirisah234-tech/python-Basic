# %%
my list = ["mango", "orange", "grape", "berries", "strawberry", "]
print(my list)

# %%
fruits = ["mango", "orange", "grape", "berries", "strawberry", "lemon"]
print(fruits)
# Out:
# ['mango', 'orange', 'grape', 'berries', 'strawberry', 'lemon']

# %%
bicycles = ["trek", "cannondale" "redline", "specialized"]
print(bicycles)
# Out:
# ['trek', 'cannondaleredline', 'specialized']

# %%
my_list = ["apple", 42, 3.142, True, "banana"]
print(my_list)
# Out:
# ['apple', 42, 3.142, True, 'banana']

# %%
print("the element in index 2 is:", my_list[3])
# Out:
# the element in index 2 is: True

# %%
print("second fruit in the fruits list is:", fruits[1].title())
# Out:
# second fruit in the fruits list is: Orange

# %%
names = ["isah", "umar", "abba", "abubakar "]
print(names)
# Out:
# ['isah', 'umar', 'abba', 'abubakar ']

# %%
print(names[3].strip().title())
# Out:
# Abubakar

# %%
second_name = names[1].title
third_name = names[2].title
print("second name and third name are ", second_name + " and " + third_name + " respectively")

# %%
courses = ["maths", "physics", "chemistry", "biology", "english"]
print("the last element in the list is ", courses[4].title())
# Out:
# the last element in the list is  English

# %%
print("the last element is ", courses[-1].title())
# Out:
# the last element is  English

# %%
print("the second element is ", courses[-4].title())
# Out:
# the second element is  Physics

# %%
my_list = ["a"]
print(my_list)
# Out:
# ['a']

# %%
my_list[0] = "b"
print(my_list)
# Out:
# ['b']

# %%
motorcycles = ["honda", "yamaha", "suzuki"]
print("original motorcycles:", motorcycles)
# Out:
# original motorcycles: ['honda', 'yamaha', 'suzuki']

# %%
motorcycles[1]= "bugatti"
print("updated motorcycles:", motorcycles)
# Out:
# updated motorcycles: ['honda', 'bugatti', 'suzuki']

# %%
my_list
my_list.append("d")
print(my_list)

# %%
my_list = ["a"]
print(my_list)
# Out:
# ['a']

# %%
my_list[0] = "b"
my_list.append("d")
print(my_list)
# Out:
# ['b']

# %%
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(my_list)
#
# NameError: name 'my_list' is not defined
