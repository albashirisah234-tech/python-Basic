# %%
my list = ["mango", "orange", "grape", "berries", "strawberry", "]
print(my list)

# %%
fruits = ["mango", "orange", "grape", "berries", "strawberry", "lemon"]
print(fruits)
# Out:
# ['mango', 'orange', 'grape', 'berries', 'strawberry', 'lemon']

# %%
bicycles = ["trek", "cannondale" "redline", "specialized"]
print(bicycles)
# Out:
# ['trek', 'cannondaleredline', 'specialized']

# %%
my_list = ["apple", 42, 3.142, True, "banana"]
print(my_list)
# Out:
# ['apple', 42, 3.142, True, 'banana']

# %%
print("the element in index 2 is:", my_list[3])
# Out:
# the element in index 2 is: True

# %%
print("second fruit in the fruits list is:", fruits[1].title())
# Out:
# second fruit in the fruits list is: Orange

# %%
names = ["isah", "umar", "abba", "abubakar "]
print(names)
# Out:
# ['isah', 'umar', 'abba', 'abubakar ']

# %%
print(names[3].strip().title())
# Out:
# Abubakar

# %%
second_name = names[1].title
third_name = names[2].title
print("second name and third name are ", second_name + " and " + third_name + " respectively")

# %%
courses = ["maths", "physics", "chemistry", "biology", "english"]
print("the last element in the list is ", courses[4].title())
# Out:
# the last element in the list is  English

# %%
print("the last element is ", courses[-1].title())
# Out:
# the last element is  English

# %%
print("the second element is ", courses[-4].title())
# Out:
# the second element is  Physics

# %%
my_list = ["a"]
print(my_list)
# Out:
# ['a']

# %%
my_list[0] = "b"
print(my_list)
# Out:
# ['b']

# %%
motorcycles = ["honda", "yamaha", "suzuki"]
print("original motorcycles:", motorcycles)
# Out:
# original motorcycles: ['honda', 'yamaha', 'suzuki']

# %%
motorcycles[1]= "bugatti"
print("updated motorcycles:", motorcycles)
# Out:
# updated motorcycles: ['honda', 'bugatti', 'suzuki']

# %%
my_list
my_list.append("d")
print(my_list)

# %%
my_list = ["a"]
print(my_list)
# Out:
# ['a']

# %%
my_list[0] = "b"
my_list.append("d")
print(my_list)
# Out:
# ['b']

# %%
attendance = []
attendance.append("zarewa")

# %%
attendance.append("albashir")

# %%
attendance.append("anas")

# %%
attendance.append("zakiyyu")

# %%
attendance.append("abbakar")
print(attendance)
# Out:
# ['zarewa', 'albashir', 'anas', 'zakiyyu', 'abbakar']

# %%
alpha = ["a", "b", "c",]
alpha.insert(3, "d")
print(alpha)
# Out:
# ['a', 'b', 'c', 'd']

# %%
num = list(range(1, 5))
print(num)
# Out:
# [1, 2, 3, 4]

# %%
num.insert(4, 5)
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
num.insert(3, 3.5)
print(num)
# Out:
# [1, 2, 3, 3.5, 4, 5]

# %%
my_favorite = "engineering mathematics"

# %%
courses = ["soil", "concrete", "steel", "geotech"]
courses.insert(4, "hydrology")
print(courses)
# Out:
# ['soil', 'concrete', 'steel', 'geotech', 'hydrology']

# %%
courses.insert(0, my_favorite)
print(courses)
# Out:
# ['engineering mathematics', 'soil', 'concrete', 'steel', 'geotech', 'hydrology']

# %%
del courses[2]
print(courses)
# Out:
# ['engineering mathematics', 'soil', 'steel', 'geotech', 'hydrology']

# %%
my_students = ["ali", "bala", "sani", "zainab"]

# %%
fruits = ["mango", "banana", "orange", "apple", "grape"]
pop_fruits = fruits.pop(3)
print("the popped fruit is:", pop_fruits.title())
# Out:
# the popped fruit is: Apple

# %%
tv_show = ["got", "breaking nad", "the wire", "the sopranos"]
print(tv_show)
# Out:
# ['got', 'breaking nad', 'the wire', 'the sopranos']

# %%
nums = [2, 1, 7, 6, 4, 5, 3]
print(nums)
# Out:
# [2, 1, 7, 6, 4, 5, 3]

# %%
nums.sort()
print(nums)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
nums.sort(reverse=True)
print(nums)
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
alpha = ["d", "a", "c", "b", "e"]
print("original list:", alpha)
print("temporarily sorted list:", sorted(alpha))
# Out:
# original list: ['d', 'a', 'c', 'b', 'e']
# temporarily sorted list: ['a', 'b', 'c', 'd', 'e']

# %%
print("the number of fruits in the list is:", len(fruits))
# Out:
# the number of fruits in the list is: 4

# %%
print("the popped fruits is:", pop_fruits.title())
# Out:
# the popped fruits is: Grape

# %%
courses = ["maths", "physics", "chemistry"]
removed_course = courses.pop()
print("the removed course is:", removed_course.title())
print(courses)
# Out:
# the removed course is: Chemistry
# ['maths', 'physics']

# %%
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(my_list)
#
# NameError: name 'my_list' is not defined
